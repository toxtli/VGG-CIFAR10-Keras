# %%
from google.colab import drive
drive.mount('gdrive')
# %cd /content/gdrive/My\ Drive/colab
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at gdrive
# /content/gdrive/My Drive/colab

# %%
from __future__ import print_function
import json
import keras
import pickle
import os.path
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.callbacks import ModelCheckpoint
from keras.callbacks import LambdaCallback
from keras import optimizers
from keras import regularizers
from keras.utils import plot_model
import numpy as np
import matplotlib.pyplot as plt

def build_model(x_shape, weight_decay, num_classes):
    # Build the network of vgg for 10 classes with massive dropout and weight decay as described in the paper.
    model = Sequential()
    weight_decay = weight_decay

    model.add(Conv2D(64, (3, 3), padding='same',
                     input_shape=x_shape, kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    model.add(Conv2D(64, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())

    model.add(MaxPooling2D(pool_size=(3, 3), strides=1))

    model.add(Conv2D(128, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))

    model.add(Conv2D(128, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())

    model.add(Flatten())
    model.add(Dense(200, kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    
    model.add(Dense(100, kernel_regularizer=regularizers.l2(weight_decay)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))
    return model


def normalize(X_train, X_test):
    # this function normalize inputs for zero mean and unit variance
    # it is used when training a model.
    # Input: training set and test set
    # Output: normalized training set and test set according to the trianing set statistics.
    mean = np.mean(X_train, axis=(0, 1, 2, 3))
    std = np.std(X_train, axis=(0, 1, 2, 3))
    X_train = (X_train - mean) / (std + 1e-7)
    X_test = (X_test - mean) / (std + 1e-7)
    return X_train, X_test


def normalize_production(x):
    # this function is used to normalize instances in production according to saved training set statistics
    # Input: X - a training set
    # Output X - a normalized training set according to normalization constants.

    # these values produced during first training and are general for the standard cifar10 training set normalization
    mean = 120.707
    std = 64.15
    return (x - mean)/(std+1e-7)


def predict(x, normalize=True, batch_size=50):
    if normalize:
        x = normalize_production(x)
    return model.predict(x, batch_size)

def updateEpoch(epoch, logs):
  to_save = num_epoch + epoch + 1
  report_data['acc'].append(logs['acc'])
  report_data['loss'].append(logs['loss'])
  report_data['val_acc'].append(logs['val_acc'])
  report_data['val_loss'].append(logs['val_loss'])
  with open(epoch_file, "w") as file:  
    file.write(str(to_save))
  with open(data_file, "wb") as file:
    pickle.dump(report_data, file)
  with open(all_file, "a+") as file:
    all_data = [to_save, report_data['acc'], report_data['val_acc'],
               report_data['loss'], report_data['val_loss']]
    file.write(json.dumps(all_data))
  print(epoch, logs)

def train(model):
    # training parameters
    batch_size = 128
    maxepoches = 100
    learning_rate = 0.1
    lr_decay = 1e-6
    lr_drop = 20
    # The data, shuffled and split between train and test sets:
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')
    x_train, x_test = normalize(x_train, x_test)

    y_train = keras.utils.to_categorical(y_train, num_classes)
    y_test = keras.utils.to_categorical(y_test, num_classes)

    def lr_scheduler(epoch):
        return learning_rate * (0.5 ** (epoch // lr_drop))

    # data augmentation
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # optimization details
    sgd = optimizers.SGD(lr=learning_rate, decay=lr_decay, momentum=0.9)
    model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
    plot_model(model, to_file='model.png')
    
    reduce_lr = keras.callbacks.LearningRateScheduler(lr_scheduler)
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    lambdaCall = LambdaCallback(on_epoch_end=updateEpoch)
    callbacks_list = [reduce_lr,checkpoint,lambdaCall]

    # training process in a for loop with learning rate drop every 20 epoches.
    history = model.fit_generator(
        datagen.flow(x_train, y_train, batch_size=batch_size),
        steps_per_epoch=x_train.shape[0] // batch_size,
        epochs=maxepoches,
        validation_data=(x_test, y_test),
        callbacks=callbacks_list,
        verbose=1)

    model.save_weights('cifar10vgg_3.h5')
    
    # summarize history for accuracy
    plt.plot(report_data['acc'])
    plt.plot(report_data['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # summarize history for loss
    plt.plot(report_data['loss'])
    plt.plot(report_data['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    return history

num_classes = 10
weight_decay = 0.0005
x_shape = [32, 32, 3]
train_bool = True
epoch_file="hw1_3_epoch_num.txt"
data_file="hw1_3_data.txt"
filepath="hw1_3_weights.best.hdf5"
all_file="hw1_3_all.txt"

model = build_model(x_shape, weight_decay, num_classes)

num_epoch = 0
if not os.path.isfile(epoch_file):
  with open(epoch_file, "w+") as file:  
    file.write(str(num_epoch))
else:
  with open(epoch_file, "r") as file:  
    num_epoch = int(file.read())

if os.path.isfile(filepath):
  model.load_weights(filepath)

if os.path.isfile(data_file):
  with open(data_file, "rb") as file:
    report_data = pickle.load(file)

# print the model summary
model.summary()

report_data = {
    "acc":[],
    "val_acc":[],
    "loss":[],
    "val_loss":[]
}

if train_bool:
    history = train(model)
else:
    model.load_weights('cifar10vgg_3.h5')

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

predicted_x = model.predict(x_test)
residuals = np.argmax(predicted_x, 1) != np.argmax(y_test, 1)

loss = sum(residuals)/len(residuals)
print("the validation 0/1 loss is: ", loss)
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 30, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 30, 30, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 30, 30, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 30, 30, 128)       147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 30, 30, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 30, 128)       512
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 115200)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               23040200
# _________________________________________________________________
# activation_5 (Activation)    (None, 200)               0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 200)               800
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               20100
# _________________________________________________________________
# activation_6 (Activation)    (None, 100)               0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 100)               400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1010
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# =================================================================
# Total params: 23,324,206
# Trainable params: 23,322,838
# Non-trainable params: 1,368
# _________________________________________________________________
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 31s 0us/step
# Epoch 1/100
# 390/390 [==============================] - 74s 189ms/step - loss: 4.1204 - acc: 0.3604 - val_loss: 3.1149 - val_acc: 0.4705
#
# Epoch 00001: val_acc improved from -inf to 0.47050, saving model to hw1_3_weights.best.hdf5
# 0 {'val_loss': 3.1148848850250244, 'val_acc': 0.4705, 'loss': 4.1203598731603375, 'acc': 0.3603565705128205, 'lr': 0.1}
# Epoch 2/100
# 390/390 [==============================] - 67s 172ms/step - loss: 2.6174 - acc: 0.4869 - val_loss: 2.0602 - val_acc: 0.5684
#
# Epoch 00002: val_acc improved from 0.47050 to 0.56840, saving model to hw1_3_weights.best.hdf5
# 1 {'val_loss': 2.0602392860412597, 'val_acc': 0.5684, 'loss': 2.616813277295663, 'acc': 0.48692653190259716, 'lr': 0.1}
# Epoch 3/100
# 390/390 [==============================] - 67s 171ms/step - loss: 1.9368 - acc: 0.5519 - val_loss: 1.6141 - val_acc: 0.6138
#
# Epoch 00003: val_acc improved from 0.56840 to 0.61380, saving model to hw1_3_weights.best.hdf5
# 2 {'val_loss': 1.6141187892913818, 'val_acc': 0.6138, 'loss': 1.936703880666195, 'acc': 0.5519128969972394, 'lr': 0.1}
# Epoch 4/100
# 390/390 [==============================] - 67s 171ms/step - loss: 1.6216 - acc: 0.5939 - val_loss: 1.3458 - val_acc: 0.6721
#
# Epoch 00004: val_acc improved from 0.61380 to 0.67210, saving model to hw1_3_weights.best.hdf5
# 3 {'val_loss': 1.3458494665145875, 'val_acc': 0.6721, 'loss': 1.6214861249480066, 'acc': 0.59400064168085, 'lr': 0.1}
# Epoch 5/100
# 390/390 [==============================] - 67s 171ms/step - loss: 1.4812 - acc: 0.6251 - val_loss: 1.7263 - val_acc: 0.5834
#
# Epoch 00005: val_acc did not improve from 0.67210
# 4 {'val_loss': 1.7263267385482788, 'val_acc': 0.5834, 'loss': 1.481255037952089, 'acc': 0.6250802053447561, 'lr': 0.1}
# Epoch 6/100
# 390/390 [==============================] - 67s 171ms/step - loss: 1.4349 - acc: 0.6407 - val_loss: 1.4277 - val_acc: 0.6432
#
# Epoch 00006: val_acc did not improve from 0.67210
# 5 {'val_loss': 1.4277039573669434, 'val_acc': 0.6432, 'loss': 1.4348865342438508, 'acc': 0.6406600897917198, 'lr': 0.1}
# Epoch 7/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.4319 - acc: 0.6491 - val_loss: 1.3673 - val_acc: 0.6837
#
# Epoch 00007: val_acc improved from 0.67210 to 0.68370, saving model to hw1_3_weights.best.hdf5
# 6 {'val_loss': 1.367263161277771, 'val_acc': 0.6837, 'loss': 1.432000404449086, 'acc': 0.6490214950272698, 'lr': 0.1}
# Epoch 8/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.4293 - acc: 0.6648 - val_loss: 1.3148 - val_acc: 0.7072
#
# Epoch 00008: val_acc improved from 0.68370 to 0.70720, saving model to hw1_3_weights.best.hdf5
# 7 {'val_loss': 1.314770209503174, 'val_acc': 0.7072, 'loss': 1.4292734431501455, 'acc': 0.6648018928074401, 'lr': 0.1}
# Epoch 9/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.4420 - acc: 0.6706 - val_loss: 1.3216 - val_acc: 0.7147
#
# Epoch 00009: val_acc improved from 0.70720 to 0.71470, saving model to hw1_3_weights.best.hdf5
# 8 {'val_loss': 1.3215529069900513, 'val_acc': 0.7147, 'loss': 1.442020938111147, 'acc': 0.6705967276035917, 'lr': 0.1}
# Epoch 10/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.4539 - acc: 0.6732 - val_loss: 1.3129 - val_acc: 0.7221
#
# Epoch 00010: val_acc improved from 0.71470 to 0.72210, saving model to hw1_3_weights.best.hdf5
# 9 {'val_loss': 1.312908906364441, 'val_acc': 0.7221, 'loss': 1.4539397052361638, 'acc': 0.6731632980238677, 'lr': 0.1}
# Epoch 11/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.4433 - acc: 0.6842 - val_loss: 1.5179 - val_acc: 0.6635
#
# Epoch 00011: val_acc did not improve from 0.72210
# 10 {'val_loss': 1.5179023422241211, 'val_acc': 0.6635, 'loss': 1.4433683583015122, 'acc': 0.6842316329995524, 'lr': 0.1}
# Epoch 12/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.4666 - acc: 0.6834 - val_loss: 1.3168 - val_acc: 0.7292
#
# Epoch 00012: val_acc improved from 0.72210 to 0.72920, saving model to hw1_3_weights.best.hdf5
# 11 {'val_loss': 1.3167510244369507, 'val_acc': 0.7292, 'loss': 1.466448310708862, 'acc': 0.683449631055502, 'lr': 0.1}
# Epoch 13/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.4753 - acc: 0.6887 - val_loss: 1.3744 - val_acc: 0.7200
#
# Epoch 00013: val_acc did not improve from 0.72920
# 12 {'val_loss': 1.37444361743927, 'val_acc': 0.72, 'loss': 1.4752675188555333, 'acc': 0.6887030798653819, 'lr': 0.1}
# Epoch 14/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.4779 - acc: 0.6920 - val_loss: 1.4318 - val_acc: 0.7097
#
# Epoch 00014: val_acc did not improve from 0.72920
# 13 {'val_loss': 1.4318328407287597, 'val_acc': 0.7097, 'loss': 1.4776538493046594, 'acc': 0.6920917548925248, 'lr': 0.1}
# Epoch 15/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.4933 - acc: 0.6921 - val_loss: 1.5442 - val_acc: 0.6896
#
# Epoch 00015: val_acc did not improve from 0.72920
# 14 {'val_loss': 1.5442200286865235, 'val_acc': 0.6896, 'loss': 1.4932462393109294, 'acc': 0.6921318575170968, 'lr': 0.1}
# Epoch 16/100
# 390/390 [==============================] - 66s 169ms/step - loss: 1.4842 - acc: 0.6975 - val_loss: 1.3978 - val_acc: 0.7231
#
# Epoch 00016: val_acc did not improve from 0.72920
# 15 {'val_loss': 1.397787956237793, 'val_acc': 0.7231, 'loss': 1.4841834453577256, 'acc': 0.6975457170164887, 'lr': 0.1}
# Epoch 17/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.4926 - acc: 0.6981 - val_loss: 1.4009 - val_acc: 0.7270
#
# Epoch 00017: val_acc did not improve from 0.72920
# 16 {'val_loss': 1.4008749103546143, 'val_acc': 0.727, 'loss': 1.492418472836482, 'acc': 0.6981673082710269, 'lr': 0.1}
# Epoch 18/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.4976 - acc: 0.7031 - val_loss: 1.4433 - val_acc: 0.7194
#
# Epoch 00018: val_acc did not improve from 0.72920
# 17 {'val_loss': 1.4432510396957396, 'val_acc': 0.7194, 'loss': 1.497689034987001, 'acc': 0.7029996791595751, 'lr': 0.1}
# Epoch 19/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.5058 - acc: 0.7026 - val_loss: 1.4882 - val_acc: 0.7067
#
# Epoch 00019: val_acc did not improve from 0.72920
# 18 {'val_loss': 1.488226358604431, 'val_acc': 0.7067, 'loss': 1.5056650155547493, 'acc': 0.7026387552133462, 'lr': 0.1}
# Epoch 20/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.5027 - acc: 0.7052 - val_loss: 1.3468 - val_acc: 0.7553
#
# Epoch 00020: val_acc improved from 0.72920 to 0.75530, saving model to hw1_3_weights.best.hdf5
# 19 {'val_loss': 1.3467644622802735, 'val_acc': 0.7553, 'loss': 1.5027836976159945, 'acc': 0.7052253769267856, 'lr': 0.1}
# Epoch 21/100
# 390/390 [==============================] - 66s 169ms/step - loss: 1.3577 - acc: 0.7401 - val_loss: 1.1899 - val_acc: 0.7809
#
# Epoch 00021: val_acc improved from 0.75530 to 0.78090, saving model to hw1_3_weights.best.hdf5
# 20 {'val_loss': 1.1899320575714112, 'val_acc': 0.7809, 'loss': 1.3576021432723608, 'acc': 0.7401146935774112, 'lr': 0.05}
# Epoch 22/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2579 - acc: 0.7506 - val_loss: 1.2552 - val_acc: 0.7495
#
# Epoch 00022: val_acc did not improve from 0.78090
# 21 {'val_loss': 1.2552078424453736, 'val_acc': 0.7495, 'loss': 1.2579690352211328, 'acc': 0.750501283323455, 'lr': 0.05}
# Epoch 23/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2388 - acc: 0.7483 - val_loss: 1.0923 - val_acc: 0.7927
#
# Epoch 00023: val_acc improved from 0.78090 to 0.79270, saving model to hw1_3_weights.best.hdf5
# 22 {'val_loss': 1.0923030408859253, 'val_acc': 0.7927, 'loss': 1.2387966575781657, 'acc': 0.7482354827978155, 'lr': 0.05}
# Epoch 24/100
# 390/390 [==============================] - 66s 169ms/step - loss: 1.2221 - acc: 0.7522 - val_loss: 1.3015 - val_acc: 0.7353
#
# Epoch 00024: val_acc did not improve from 0.79270
# 23 {'val_loss': 1.3015078886032105, 'val_acc': 0.7353, 'loss': 1.2220804446929916, 'acc': 0.7521655438112302, 'lr': 0.05}
# Epoch 25/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2294 - acc: 0.7497 - val_loss: 1.1653 - val_acc: 0.7728
#
# Epoch 00025: val_acc did not improve from 0.79270
# 24 {'val_loss': 1.165287120437622, 'val_acc': 0.7728, 'loss': 1.2293882255642927, 'acc': 0.749759384061344, 'lr': 0.05}
# Epoch 26/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2252 - acc: 0.7528 - val_loss: 1.1628 - val_acc: 0.7717
#
# Epoch 00026: val_acc did not improve from 0.79270
# 25 {'val_loss': 1.1627868621826172, 'val_acc': 0.7717, 'loss': 1.2251499184898202, 'acc': 0.7528071863971768, 'lr': 0.05}
# Epoch 27/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2273 - acc: 0.7563 - val_loss: 1.2108 - val_acc: 0.7606
#
# Epoch 00027: val_acc did not improve from 0.79270
# 26 {'val_loss': 1.2107693761825562, 'val_acc': 0.7606, 'loss': 1.2270951188830639, 'acc': 0.7563562720947095, 'lr': 0.05}
# Epoch 28/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2270 - acc: 0.7591 - val_loss: 1.2120 - val_acc: 0.7612
#
# Epoch 00028: val_acc did not improve from 0.79270
# 27 {'val_loss': 1.2120457397460938, 'val_acc': 0.7612, 'loss': 1.2270231277161696, 'acc': 0.7590632018157217, 'lr': 0.05}
# Epoch 29/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2294 - acc: 0.7569 - val_loss: 1.2958 - val_acc: 0.7401
#
# Epoch 00029: val_acc did not improve from 0.79270
# 28 {'val_loss': 1.2957988250732422, 'val_acc': 0.7401, 'loss': 1.2292298680128944, 'acc': 0.7569377606481859, 'lr': 0.05}
# Epoch 30/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2366 - acc: 0.7565 - val_loss: 1.3854 - val_acc: 0.7307
#
# Epoch 00030: val_acc did not improve from 0.79270
# 29 {'val_loss': 1.385443860244751, 'val_acc': 0.7307, 'loss': 1.2365491994114919, 'acc': 0.7565367340773851, 'lr': 0.05}
# Epoch 31/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2292 - acc: 0.7607 - val_loss: 1.2632 - val_acc: 0.7503
#
# Epoch 00031: val_acc did not improve from 0.79270
# 30 {'val_loss': 1.2632303176879882, 'val_acc': 0.7503, 'loss': 1.229163757187455, 'acc': 0.7607475136349053, 'lr': 0.05}
# Epoch 32/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2356 - acc: 0.7601 - val_loss: 1.2218 - val_acc: 0.7657
#
# Epoch 00032: val_acc did not improve from 0.79270
# 31 {'val_loss': 1.221790266609192, 'val_acc': 0.7657, 'loss': 1.2355191804753078, 'acc': 0.7601860763363476, 'lr': 0.05}
# Epoch 33/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2483 - acc: 0.7586 - val_loss: 1.1899 - val_acc: 0.7829
#
# Epoch 00033: val_acc did not improve from 0.79270
# 32 {'val_loss': 1.1898806497573853, 'val_acc': 0.7829, 'loss': 1.2483943267093471, 'acc': 0.7585819698045527, 'lr': 0.05}
# Epoch 34/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2387 - acc: 0.7629 - val_loss: 1.2023 - val_acc: 0.7744
#
# Epoch 00034: val_acc did not improve from 0.79270
# 33 {'val_loss': 1.2023190982818603, 'val_acc': 0.7744, 'loss': 1.2388973566519743, 'acc': 0.7628729547450739, 'lr': 0.05}
# Epoch 35/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2343 - acc: 0.7643 - val_loss: 1.2678 - val_acc: 0.7558
#
# Epoch 00035: val_acc did not improve from 0.79270
# 34 {'val_loss': 1.267775419998169, 'val_acc': 0.7558, 'loss': 1.2340835436514106, 'acc': 0.7643567532501735, 'lr': 0.05}
# Epoch 36/100
# 390/390 [==============================] - 67s 171ms/step - loss: 1.2376 - acc: 0.7651 - val_loss: 1.2408 - val_acc: 0.7662
#
# Epoch 00036: val_acc did not improve from 0.79270
# 35 {'val_loss': 1.2407615251541138, 'val_acc': 0.7662, 'loss': 1.2375589615265299, 'acc': 0.765078601219121, 'lr': 0.05}
# Epoch 37/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2482 - acc: 0.7629 - val_loss: 1.1242 - val_acc: 0.8008
#
# Epoch 00037: val_acc improved from 0.79270 to 0.80080, saving model to hw1_3_weights.best.hdf5
# 36 {'val_loss': 1.1241849131584167, 'val_acc': 0.8008, 'loss': 1.2481875588659066, 'acc': 0.7629732114403608, 'lr': 0.05}
# Epoch 38/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2394 - acc: 0.7647 - val_loss: 1.2497 - val_acc: 0.7594
#
# Epoch 00038: val_acc did not improve from 0.80080
# 37 {'val_loss': 1.249663027381897, 'val_acc': 0.7594, 'loss': 1.2395193529771542, 'acc': 0.7646775746100752, 'lr': 0.05}
# Epoch 39/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.2471 - acc: 0.7662 - val_loss: 1.1736 - val_acc: 0.7906
#
# Epoch 00039: val_acc did not improve from 0.80080
# 38 {'val_loss': 1.1736082887649537, 'val_acc': 0.7906, 'loss': 1.2471063740558643, 'acc': 0.7662215271094001, 'lr': 0.05}
# Epoch 40/100
# 390/390 [==============================] - 66s 169ms/step - loss: 1.2441 - acc: 0.7661 - val_loss: 1.1387 - val_acc: 0.7978
#
# Epoch 00040: val_acc did not improve from 0.80080
# 39 {'val_loss': 1.1386903366088867, 'val_acc': 0.7978, 'loss': 1.2440064338143146, 'acc': 0.7661212704714805, 'lr': 0.05}
# Epoch 41/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.1412 - acc: 0.7949 - val_loss: 1.0517 - val_acc: 0.8167
#
# Epoch 00041: val_acc improved from 0.80080 to 0.81670, saving model to hw1_3_weights.best.hdf5
# 40 {'val_loss': 1.0516892984390258, 'val_acc': 0.8167, 'loss': 1.1412219169777023, 'acc': 0.7948748796537667, 'lr': 0.025}
# Epoch 42/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0736 - acc: 0.8030 - val_loss: 0.9982 - val_acc: 0.8221
#
# Epoch 00042: val_acc improved from 0.81670 to 0.82210, saving model to hw1_3_weights.best.hdf5
# 41 {'val_loss': 0.9981928995132446, 'val_acc': 0.8221, 'loss': 1.0733171237520887, 'acc': 0.8030959255694579, 'lr': 0.025}
# Epoch 43/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0451 - acc: 0.8058 - val_loss: 1.2653 - val_acc: 0.7499
#
# Epoch 00043: val_acc did not improve from 0.82210
# 42 {'val_loss': 1.265330823326111, 'val_acc': 0.7499, 'loss': 1.0450353488196997, 'acc': 0.8058229066218785, 'lr': 0.025}
# Epoch 44/100
# 390/390 [==============================] - 66s 169ms/step - loss: 1.0248 - acc: 0.8042 - val_loss: 0.9498 - val_acc: 0.8268
#
# Epoch 00044: val_acc improved from 0.82210 to 0.82680, saving model to hw1_3_weights.best.hdf5
# 43 {'val_loss': 0.9497907674789429, 'val_acc': 0.8268, 'loss': 1.024560345875211, 'acc': 0.8043190567471257, 'lr': 0.025}
# Epoch 45/100
# 390/390 [==============================] - 66s 169ms/step - loss: 1.0138 - acc: 0.8047 - val_loss: 0.9996 - val_acc: 0.8110
#
# Epoch 00045: val_acc did not improve from 0.82680
# 44 {'val_loss': 0.9996144660949707, 'val_acc': 0.811, 'loss': 1.0137679031119349, 'acc': 0.8046398780687826, 'lr': 0.025}
# Epoch 46/100
# 390/390 [==============================] - 66s 169ms/step - loss: 1.0053 - acc: 0.8063 - val_loss: 0.9788 - val_acc: 0.8163
#
# Epoch 00046: val_acc did not improve from 0.82680
# 45 {'val_loss': 0.9788149766921997, 'val_acc': 0.8163, 'loss': 1.005333072583875, 'acc': 0.8063442412958644, 'lr': 0.025}
# Epoch 47/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.9974 - acc: 0.8067 - val_loss: 1.0115 - val_acc: 0.8088
#
# Epoch 00047: val_acc did not improve from 0.82680
# 46 {'val_loss': 1.0114983549118042, 'val_acc': 0.8088, 'loss': 0.9973097885882659, 'acc': 0.8067653191980736, 'lr': 0.025}
# Epoch 48/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0013 - acc: 0.8070 - val_loss: 0.9536 - val_acc: 0.8189
#
# Epoch 00048: val_acc did not improve from 0.82680
# 47 {'val_loss': 0.9535665416717529, 'val_acc': 0.8189, 'loss': 1.0012557013202332, 'acc': 0.8069457811998717, 'lr': 0.025}
# Epoch 49/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0007 - acc: 0.8055 - val_loss: 1.0453 - val_acc: 0.7970
#
# Epoch 00049: val_acc did not improve from 0.82680
# 48 {'val_loss': 1.0453099611282348, 'val_acc': 0.797, 'loss': 1.0006732721721894, 'acc': 0.8054619826756496, 'lr': 0.025}
# Epoch 50/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.9986 - acc: 0.8089 - val_loss: 1.0739 - val_acc: 0.7825
#
# Epoch 00050: val_acc did not improve from 0.82680
# 49 {'val_loss': 1.0738660201072694, 'val_acc': 0.7825, 'loss': 0.9987192393917284, 'acc': 0.8088506576454253, 'lr': 0.025}
# Epoch 51/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0050 - acc: 0.8050 - val_loss: 0.9917 - val_acc: 0.8137
#
# Epoch 00051: val_acc did not improve from 0.82680
# 50 {'val_loss': 0.9916900985717774, 'val_acc': 0.8137, 'loss': 1.0049377814446805, 'acc': 0.8050810073597675, 'lr': 0.025}
# Epoch 52/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0026 - acc: 0.8072 - val_loss: 0.9562 - val_acc: 0.8255
#
# Epoch 00052: val_acc did not improve from 0.82680
# 51 {'val_loss': 0.9561797338485718, 'val_acc': 0.8255, 'loss': 1.0026613256661296, 'acc': 0.8071663458262417, 'lr': 0.025}
# Epoch 53/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0024 - acc: 0.8079 - val_loss: 0.9314 - val_acc: 0.8251
#
# Epoch 00053: val_acc did not improve from 0.82680
# 52 {'val_loss': 0.9313875597000122, 'val_acc': 0.8251, 'loss': 1.0024468654770862, 'acc': 0.8078881937378218, 'lr': 0.025}
# Epoch 54/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0013 - acc: 0.8091 - val_loss: 1.0201 - val_acc: 0.8087
#
# Epoch 00054: val_acc did not improve from 0.82680
# 53 {'val_loss': 1.020106302833557, 'val_acc': 0.8087, 'loss': 1.001034006003122, 'acc': 0.809191530317613, 'lr': 0.025}
# Epoch 55/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0085 - acc: 0.8066 - val_loss: 1.0496 - val_acc: 0.7977
#
# Epoch 00055: val_acc did not improve from 0.82680
# 54 {'val_loss': 1.0496455953598023, 'val_acc': 0.7977, 'loss': 1.008433606328588, 'acc': 0.8066249598782147, 'lr': 0.025}
# Epoch 56/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0034 - acc: 0.8109 - val_loss: 0.9560 - val_acc: 0.8255
#
# Epoch 00056: val_acc did not improve from 0.82680
# 55 {'val_loss': 0.9559955959320068, 'val_acc': 0.8255, 'loss': 1.0034836519976857, 'acc': 0.8108557908627556, 'lr': 0.025}
# Epoch 57/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0058 - acc: 0.8089 - val_loss: 1.0049 - val_acc: 0.8093
#
# Epoch 00057: val_acc did not improve from 0.82680
# 56 {'val_loss': 1.0048825439453124, 'val_acc': 0.8093, 'loss': 1.005649217933579, 'acc': 0.808910811658773, 'lr': 0.025}
# Epoch 58/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0031 - acc: 0.8128 - val_loss: 0.9798 - val_acc: 0.8176
#
# Epoch 00058: val_acc did not improve from 0.82680
# 57 {'val_loss': 0.979800566482544, 'val_acc': 0.8176, 'loss': 1.0031339488887696, 'acc': 0.8128208212642896, 'lr': 0.025}
# Epoch 59/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0036 - acc: 0.8123 - val_loss: 0.9570 - val_acc: 0.8288
#
# Epoch 00059: val_acc improved from 0.82680 to 0.82880, saving model to hw1_3_weights.best.hdf5
# 58 {'val_loss': 0.9570332124710083, 'val_acc': 0.8288, 'loss': 1.0035924657361799, 'acc': 0.8122393326725683, 'lr': 0.025}
# Epoch 60/100
# 390/390 [==============================] - 66s 170ms/step - loss: 1.0042 - acc: 0.8114 - val_loss: 0.9922 - val_acc: 0.8219
#
# Epoch 00060: val_acc did not improve from 0.82880
# 59 {'val_loss': 0.9921982656478882, 'val_acc': 0.8219, 'loss': 1.004125806089774, 'acc': 0.811457330728518, 'lr': 0.025}
# Epoch 61/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.9356 - acc: 0.8297 - val_loss: 0.8382 - val_acc: 0.8609
#
# Epoch 00061: val_acc improved from 0.82880 to 0.86090, saving model to hw1_3_weights.best.hdf5
# 60 {'val_loss': 0.8381551260948181, 'val_acc': 0.8609, 'loss': 0.9355971096110413, 'acc': 0.8297240937180652, 'lr': 0.0125}
# Epoch 62/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8903 - acc: 0.8400 - val_loss: 0.8471 - val_acc: 0.8521
#
# Epoch 00062: val_acc did not improve from 0.86090
# 61 {'val_loss': 0.8470858669281006, 'val_acc': 0.8521, 'loss': 0.8901638099693663, 'acc': 0.8400705806674351, 'lr': 0.0125}
# Epoch 63/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8672 - acc: 0.8417 - val_loss: 0.8594 - val_acc: 0.8467
#
# Epoch 00063: val_acc did not improve from 0.86090
# 62 {'val_loss': 0.859367119216919, 'val_acc': 0.8467, 'loss': 0.8671309007143493, 'acc': 0.8416947385306385, 'lr': 0.0125}
# Epoch 64/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8512 - acc: 0.8440 - val_loss: 0.8762 - val_acc: 0.8390
#
# Epoch 00064: val_acc did not improve from 0.86090
# 63 {'val_loss': 0.8761697724342347, 'val_acc': 0.839, 'loss': 0.8512394728284254, 'acc': 0.843940487610135, 'lr': 0.0125}
# Epoch 65/100
# 390/390 [==============================] - 67s 171ms/step - loss: 0.8438 - acc: 0.8445 - val_loss: 0.8309 - val_acc: 0.8499
#
# Epoch 00065: val_acc did not improve from 0.86090
# 64 {'val_loss': 0.8309021116256714, 'val_acc': 0.8499, 'loss': 0.8439441048299651, 'acc': 0.8444618222841208, 'lr': 0.0125}
# Epoch 66/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8369 - acc: 0.8421 - val_loss: 0.8376 - val_acc: 0.8421
#
# Epoch 00066: val_acc did not improve from 0.86090
# 65 {'val_loss': 0.8376294877052307, 'val_acc': 0.8421, 'loss': 0.8369702260234931, 'acc': 0.8420957651205616, 'lr': 0.0125}
# Epoch 67/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8321 - acc: 0.8429 - val_loss: 0.8295 - val_acc: 0.8434
#
# Epoch 00067: val_acc did not improve from 0.86090
# 66 {'val_loss': 0.8295005009174347, 'val_acc': 0.8434, 'loss': 0.832192320834378, 'acc': 0.8428376644209176, 'lr': 0.0125}
# Epoch 68/100
# 390/390 [==============================] - 67s 171ms/step - loss: 0.8244 - acc: 0.8445 - val_loss: 0.7892 - val_acc: 0.8550
#
# Epoch 00068: val_acc did not improve from 0.86090
# 67 {'val_loss': 0.789173433303833, 'val_acc': 0.855, 'loss': 0.8243035712148808, 'acc': 0.8445420275715095, 'lr': 0.0125}
# Epoch 69/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8226 - acc: 0.8441 - val_loss: 0.7953 - val_acc: 0.8507
#
# Epoch 00069: val_acc did not improve from 0.86090
# 68 {'val_loss': 0.7953139841079712, 'val_acc': 0.8507, 'loss': 0.8221782855510252, 'acc': 0.8441610522747499, 'lr': 0.0125}
# Epoch 70/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8262 - acc: 0.8413 - val_loss: 0.8558 - val_acc: 0.8370
#
# Epoch 00070: val_acc did not improve from 0.86090
# 69 {'val_loss': 0.8557782336235047, 'val_acc': 0.837, 'loss': 0.826184434637566, 'acc': 0.8413137632338787, 'lr': 0.0125}
# Epoch 71/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8084 - acc: 0.8482 - val_loss: 0.8151 - val_acc: 0.8466
#
# Epoch 00071: val_acc did not improve from 0.86090
# 70 {'val_loss': 0.8150810267448425, 'val_acc': 0.8466, 'loss': 0.8083038279594884, 'acc': 0.8482114212192478, 'lr': 0.0125}
# Epoch 72/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8143 - acc: 0.8436 - val_loss: 0.8611 - val_acc: 0.8359
#
# Epoch 00072: val_acc did not improve from 0.86090
# 71 {'val_loss': 0.8610574778556823, 'val_acc': 0.8359, 'loss': 0.8144885894959272, 'acc': 0.843559512389865, 'lr': 0.0125}
# Epoch 73/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8112 - acc: 0.8471 - val_loss: 0.7927 - val_acc: 0.8520
#
# Epoch 00073: val_acc did not improve from 0.86090
# 72 {'val_loss': 0.792731586933136, 'val_acc': 0.852, 'loss': 0.8111452543471614, 'acc': 0.8471487006928472, 'lr': 0.0125}
# Epoch 74/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8062 - acc: 0.8477 - val_loss: 0.8573 - val_acc: 0.8329
#
# Epoch 00074: val_acc did not improve from 0.86090
# 73 {'val_loss': 0.8573147510528565, 'val_acc': 0.8329, 'loss': 0.8058927569742725, 'acc': 0.8477101379531601, 'lr': 0.0125}
# Epoch 75/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8088 - acc: 0.8455 - val_loss: 0.8057 - val_acc: 0.8495
#
# Epoch 00075: val_acc did not improve from 0.86090
# 74 {'val_loss': 0.8056855538368225, 'val_acc': 0.8495, 'loss': 0.8086574044906829, 'acc': 0.8455646455115832, 'lr': 0.0125}
# Epoch 76/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8107 - acc: 0.8461 - val_loss: 0.8817 - val_acc: 0.8254
#
# Epoch 00076: val_acc did not improve from 0.86090
# 75 {'val_loss': 0.8816652898788452, 'val_acc': 0.8254, 'loss': 0.8107475423453364, 'acc': 0.8461260827910185, 'lr': 0.0125}
# Epoch 77/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8063 - acc: 0.8452 - val_loss: 0.8375 - val_acc: 0.8398
#
# Epoch 00077: val_acc did not improve from 0.86090
# 76 {'val_loss': 0.8374813257217407, 'val_acc': 0.8398, 'loss': 0.8061660508486871, 'acc': 0.8452839268718655, 'lr': 0.0125}
# Epoch 78/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8188 - acc: 0.8445 - val_loss: 0.8019 - val_acc: 0.8507
#
# Epoch 00078: val_acc did not improve from 0.86090
# 77 {'val_loss': 0.8019030849456787, 'val_acc': 0.8507, 'loss': 0.8187298049596322, 'acc': 0.8445420276288769, 'lr': 0.0125}
# Epoch 79/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8068 - acc: 0.8482 - val_loss: 0.8234 - val_acc: 0.8405
#
# Epoch 00079: val_acc did not improve from 0.86090
# 78 {'val_loss': 0.823372285938263, 'val_acc': 0.8405, 'loss': 0.8066911563913066, 'acc': 0.8482515239011871, 'lr': 0.0125}
# Epoch 80/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.8216 - acc: 0.8419 - val_loss: 0.8100 - val_acc: 0.8518
#
# Epoch 00080: val_acc did not improve from 0.86090
# 79 {'val_loss': 0.8099707921028138, 'val_acc': 0.8518, 'loss': 0.821637983042191, 'acc': 0.841915303176131, 'lr': 0.0125}
# Epoch 81/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.7638 - acc: 0.8607 - val_loss: 0.7242 - val_acc: 0.8686
#
# Epoch 00081: val_acc improved from 0.86090 to 0.86860, saving model to hw1_3_weights.best.hdf5
# 80 {'val_loss': 0.7242404225349426, 'val_acc': 0.8686, 'loss': 0.7638337458407684, 'acc': 0.8607836060123181, 'lr': 0.00625}
# Epoch 82/100
# 390/390 [==============================] - 66s 169ms/step - loss: 0.7297 - acc: 0.8695 - val_loss: 0.7657 - val_acc: 0.8590
#
# Epoch 00082: val_acc did not improve from 0.86860
# 81 {'val_loss': 0.7656891663551331, 'val_acc': 0.859, 'loss': 0.7296186319558636, 'acc': 0.8695460378951586, 'lr': 0.00625}
# Epoch 83/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.7161 - acc: 0.8715 - val_loss: 0.7543 - val_acc: 0.8605
#
# Epoch 00083: val_acc did not improve from 0.86860
# 82 {'val_loss': 0.7542970517158508, 'val_acc': 0.8605, 'loss': 0.7161830754512619, 'acc': 0.8714910170417739, 'lr': 0.00625}
# Epoch 84/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.7116 - acc: 0.8711 - val_loss: 0.7263 - val_acc: 0.8674
#
# Epoch 00084: val_acc did not improve from 0.86860
# 83 {'val_loss': 0.7263257093429566, 'val_acc': 0.8674, 'loss': 0.7114841960009605, 'acc': 0.8711501443313413, 'lr': 0.00625}
# Epoch 85/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.7026 - acc: 0.8735 - val_loss: 0.6977 - val_acc: 0.8716
#
# Epoch 00085: val_acc improved from 0.86860 to 0.87160, saving model to hw1_3_weights.best.hdf5
# 84 {'val_loss': 0.6976870885848999, 'val_acc': 0.8716, 'loss': 0.7023359999314003, 'acc': 0.8734760987938387, 'lr': 0.00625}
# Epoch 86/100
# 390/390 [==============================] - 66s 169ms/step - loss: 0.6945 - acc: 0.8727 - val_loss: 0.7263 - val_acc: 0.8654
#
# Epoch 00086: val_acc did not improve from 0.87160
# 85 {'val_loss': 0.726275203704834, 'val_acc': 0.8654, 'loss': 0.6943998966302709, 'acc': 0.8727542508631362, 'lr': 0.00625}
# Epoch 87/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.6839 - acc: 0.8766 - val_loss: 0.7370 - val_acc: 0.8621
#
# Epoch 00087: val_acc did not improve from 0.87160
# 86 {'val_loss': 0.7370177928924561, 'val_acc': 0.8621, 'loss': 0.6837861802205467, 'acc': 0.8766041065126724, 'lr': 0.00625}
# Epoch 88/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.6859 - acc: 0.8722 - val_loss: 0.7424 - val_acc: 0.8598
#
# Epoch 00088: val_acc did not improve from 0.87160
# 87 {'val_loss': 0.7424302629470825, 'val_acc': 0.8598, 'loss': 0.6858964153004641, 'acc': 0.8721727622522923, 'lr': 0.00625}
# Epoch 89/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.6855 - acc: 0.8719 - val_loss: 0.6891 - val_acc: 0.8728
#
# Epoch 00089: val_acc improved from 0.87160 to 0.87280, saving model to hw1_3_weights.best.hdf5
# 88 {'val_loss': 0.6891347537994384, 'val_acc': 0.8728, 'loss': 0.6854791415208114, 'acc': 0.8719120949439831, 'lr': 0.00625}
# Epoch 90/100
# 390/390 [==============================] - 66s 169ms/step - loss: 0.6717 - acc: 0.8762 - val_loss: 0.7512 - val_acc: 0.8611
#
# Epoch 00090: val_acc did not improve from 0.87280
# 89 {'val_loss': 0.7512011817932129, 'val_acc': 0.8611, 'loss': 0.6716253293757642, 'acc': 0.8762632338404847, 'lr': 0.00625}
# Epoch 91/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.6710 - acc: 0.8753 - val_loss: 0.7042 - val_acc: 0.8699
#
# Epoch 00091: val_acc did not improve from 0.87280
# 90 {'val_loss': 0.7041941662788391, 'val_acc': 0.8699, 'loss': 0.6708404744593118, 'acc': 0.875300770009371, 'lr': 0.00625}
# Epoch 92/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.6653 - acc: 0.8756 - val_loss: 0.7057 - val_acc: 0.8673
#
# Epoch 00092: val_acc did not improve from 0.87280
# 91 {'val_loss': 0.7056657041549682, 'val_acc': 0.8673, 'loss': 0.6653046625563837, 'acc': 0.8756416426050689, 'lr': 0.00625}
# Epoch 93/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.6651 - acc: 0.8743 - val_loss: 0.7313 - val_acc: 0.8599
#
# Epoch 00093: val_acc did not improve from 0.87280
# 92 {'val_loss': 0.7312873745918274, 'val_acc': 0.8599, 'loss': 0.6649878600449144, 'acc': 0.8743984600577478, 'lr': 0.00625}
# Epoch 94/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.6642 - acc: 0.8731 - val_loss: 0.7187 - val_acc: 0.8634
#
# Epoch 00094: val_acc did not improve from 0.87280
# 93 {'val_loss': 0.7186572435379028, 'val_acc': 0.8634, 'loss': 0.6642320906461949, 'acc': 0.8730550208533847, 'lr': 0.00625}
# Epoch 95/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.6601 - acc: 0.8757 - val_loss: 0.6636 - val_acc: 0.8802
#
# Epoch 00095: val_acc improved from 0.87280 to 0.88020, saving model to hw1_3_weights.best.hdf5
# 94 {'val_loss': 0.6636499605178833, 'val_acc': 0.8802, 'loss': 0.6602609274017914, 'acc': 0.8756616939747223, 'lr': 0.00625}
# Epoch 96/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.6615 - acc: 0.8734 - val_loss: 0.7135 - val_acc: 0.8645
#
# Epoch 00096: val_acc did not improve from 0.88020
# 95 {'val_loss': 0.7135431793212891, 'val_acc': 0.8645, 'loss': 0.6614783140455717, 'acc': 0.8734359961501443, 'lr': 0.00625}
# Epoch 97/100
# 390/390 [==============================] - 66s 169ms/step - loss: 0.6564 - acc: 0.8743 - val_loss: 0.6875 - val_acc: 0.8692
#
# Epoch 00097: val_acc did not improve from 0.88020
# 96 {'val_loss': 0.6874669140815735, 'val_acc': 0.8692, 'loss': 0.6563203325820803, 'acc': 0.8742781520884199, 'lr': 0.00625}
# Epoch 98/100
# 390/390 [==============================] - 66s 169ms/step - loss: 0.6582 - acc: 0.8755 - val_loss: 0.6769 - val_acc: 0.8716
#
# Epoch 00098: val_acc did not improve from 0.88020
# 97 {'val_loss': 0.6769103946208954, 'val_acc': 0.8716, 'loss': 0.6582712317300906, 'acc': 0.8754611806606382, 'lr': 0.00625}
# Epoch 99/100
# 390/390 [==============================] - 66s 169ms/step - loss: 0.6523 - acc: 0.8759 - val_loss: 0.6948 - val_acc: 0.8680
#
# Epoch 00099: val_acc did not improve from 0.88020
# 98 {'val_loss': 0.6948084403991699, 'val_acc': 0.868, 'loss': 0.6522548359328445, 'acc': 0.8759624638693586, 'lr': 0.00625}
# Epoch 100/100
# 390/390 [==============================] - 66s 170ms/step - loss: 0.6506 - acc: 0.8759 - val_loss: 0.7583 - val_acc: 0.8450
#
# Epoch 00100: val_acc did not improve from 0.88020
# 99 {'val_loss': 0.75830604429245, 'val_acc': 0.845, 'loss': 0.6506097832091695, 'acc': 0.8759624639267259, 'lr': 0.00625}
# the validation 0/1 loss is:  0.8997
